# %%
from __future__ import division, print_function
import networkx as nx

# %%
node_file = "academia-ri-nodes.txt"
edge_file = "academia-ri-edges.txt"

# %%
# Each line is a node id and a topic name property of that node
node_list = []
with open(node_file,"r") as f:
    node_header = f.readline()
    node_contents = f.readlines()
    for node_line in node_contents:
        node_id, name = node_line.strip().split("\t")
        entry = (int(node_id), name)
        node_list.append(entry)

# %%
# Each edge has a source/target node id and a weight
edge_list = []
with open(edge_file,"r") as f:
    edge_header = f.readline()
    edge_contents = f.readlines()
    for edge_line in edge_contents:
        source, target, weight = edge_line.strip().split("\t")
        entry = int(source), int(target), float(weight)
        edge_list.append(entry)

# %%
def build_graph(node_list, edge_list):
    G = nx.Graph()
    for node_id, name in node_list:
        G.add_node(node_id, name=name)
    
    for src, tar, weight in edge_list:
        G.add_edge(src, tar, weight=weight, distance=1/weight)
        
    return G

# %%
# Build up the Graph G from node and edge lists
# with name and weight properties respectively
G = build_graph(node_list, edge_list)

# %%
# Straight indexing gives the edges of node [n], none right now
# .node indexing gives other keynamed properties of node [n]
print(G[8])
print(G.node[8])
# Out:
# {128: {'distance': 0.6106870229007634, 'weight': 1.6375}, 928: {'distance': 0.4948535233570863, 'weight': 2.0208}, 803: {'distance': 0.23475280529602327, 'weight': 4.2598}, 4486: {'distance': 0.5848295221942804, 'weight': 1.7099}, 188: {'distance': 0.25848476232326106, 'weight': 3.8687}, 813: {'distance': 0.5516936996579499, 'weight': 1.8126}, 184: {'distance': 0.46722422090361165, 'weight': 2.1403}, 2418: {'distance': 0.512610211195407, 'weight': 1.9508}, 4195: {'distance': 0.8707767328456983, 'weight': 1.1484}, 1237: {'distance': 0.6752194463200539, 'weight': 1.481}, 885: {'distance': 0.8471704506946799, 'weight': 1.1804}, 696: {'distance': 0.5003001801080649, 'weight': 1.9988}, 922: {'distance': 0.513136288998358, 'weight': 1.9488}, 915: {'distance': 0.6971070059254095, 'weight': 1.4345}, 797: {'distance': 0.7046719751955465, 'weight': 1.4191}, 767: {'distance': 0.6438320885912954, 'weight': 1.5532}}
# {'name': 'Critical Theory'}

# %%
# Find the max degree by building a list of all degrees
# 2-tupled with the node name
degrees = []
for node in G.nodes_iter():
    degree = G.degree(node)
    degrees.append((G.node[node]['name'], degree))

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-396-1b5c30d4b251> in <module>()
# ----> 1 list(*nx.degree(G))
#
# TypeError: list() takes at most 1 argument (466 given)

# %%
# Sort descending by the degree
degrees.sort(key=lambda x: x[1],reverse=True)

# %%
# This allows a summary for a single node which
# does the lookups for the names of other nodes.
def explain_G(G, node_id):
    parent_node = G.node[node_id]['name']
    print("{0} is connected to these topics:\n".format(parent_node))
    print("\t{0:25}\t{1:10}".format('Field','Relatedness'))
    for n in G[node_id]:
        name = G.node[n]['name']
        weight = G[node_id][n]['weight']
        print("\t  {0:25}\t{1:10}".format(name,weight))
        
explain_G(G,8)
# Out:
# Critical Theory is connected to these topics:
#
# 	Field                    	Relatedness
# 	  History                  	    1.6375
# 	  Media Studies            	    2.0208
# 	  Philosophy               	    4.2598
# 	  Political Science        	    1.7099
# 	  Cultural Studies         	    3.8687
# 	  Political Philosophy     	    1.8126
# 	  Sociology                	    2.1403
# 	  Literature               	    1.9508
# 	  Cultural Theory          	    1.1484
# 	  Social Sciences          	     1.481
# 	  English Literature       	    1.1804
# 	  Gender Studies           	    1.9988
# 	  Education                	    1.9488
# 	  Art History              	    1.4345
# 	  International Relations  	    1.4191
# 	  Anthropology             	    1.5532

# %%
# With the weighted graph built, we can
# find the page rank of all nodes.
rank = nx.pagerank(G)
# And can also do a "binary" page rank
# which treats all weights as unity.
unit_rank = nx.pagerank(G, weight=None)

# %%
# build lists from the dictionaries
# to be sorted.
rank_list = []
unit_rank_list = []
for key in rank:
    rank_list.append((key,rank[key]))
    unit_rank_list.append((key,unit_rank[key]))

# %%
# Sort descending
rank_list.sort(key=lambda x: x[1], reverse=True)
unit_rank_list.sort(key=lambda x: x[1], reverse=True)

# %%
# Remap the node keys to their real names
names_rank = []
names_unit_rank = []

for key, score in rank_list:
    names_rank.append((G.node[key]["name"],score))
for key,score in unit_rank_list:
    names_unit_rank.append((G.node[key]["name"],score))

# %%
# The output of the two rank algorithms
tot = 0
for each in names_rank[:10]:
    print("  {0:25}\t{1:2.5f}".format(each[0],each[1]))
    #tot += each[1]
#print(tot)
print()
tot = 0
for each in names_unit_rank[:10]:
    print("  {0:25}\t{1:2.5f}".format(each[0],each[1]))
    #tot += each[1]
#print(tot)
# Out:
#   Education                	0.04734
#   Social Sciences          	0.03252
#   History                  	0.02854
#   Philosophy               	0.02528
#   Computer Science         	0.02461
#   Business                 	0.02253
#   Sociology                	0.02164
#   International Relations  	0.02003
#   Psychology               	0.01546
#   Anthropology             	0.01507
#
#   Education                	0.02647
#   Computer Science         	0.01964
#   Philosophy               	0.01785
#   History                  	0.01674
#   Psychology               	0.01411
#   International Relations  	0.01383
#   Sociology                	0.01299
#   Archaeology              	0.01243
#   Social Sciences          	0.01217
#   Environmental Sustainability	0.01181

# %%
# And now just the output by pure degree
# Note differences among all three outputs.
E = len(G.edges())
for name, deg in degrees[:10]:
    print("  {0:25}\t{1:2f}".format(name,deg/(2*E)))
# Out:
#   Education                	0.035165
#   Computer Science         	0.024176
#   Philosophy               	0.022711
#   History                  	0.021612
#   International Relations  	0.018315
#   Sociology                	0.017949
#   Social Sciences          	0.017949
#   Psychology               	0.016850
#   Communication            	0.016850
#   Business                 	0.016117

# %%
# This is slow!!! ~ 5 min
nx.average_node_connectivity(G)
# Out:
# 1.4371775347270295

# %%
all_pais = nx.all_pairs_node_connectivity(G)

# %%
all_pais[8]
# Out:
# {26: 22,
#  27: 14,
#  32: 5,
#  37: 2,
#  38: 5,
#  39: 23,
#  45: 6,
#  46: 1,
#  47: 1,
#  48: 1,
#  49: 12,
#  50: 2,
#  55: 1,
#  60: 2,
#  62: 1,
#  72: 1,
#  73: 4,
#  77: 5,
#  78: 1,
#  87: 1,
#  94: 0,
#  106: 5,
#  128: 1,
#  130: 3,
#  131: 1,
#  133: 1,
#  135: 1,
#  136: 1,
#  137: 2,
#  140: 0,
#  145: 0,
#  146: 4,
#  148: 4,
#  153: 2,
#  155: 2,
#  156: 1,
#  159: 1,
#  161: 2,
#  173: 0,
#  184: 1,
#  188: 1,
#  189: 1,
#  201: 2,
#  208: 1,
#  209: 1,
#  221: 1,
#  226: 1,
#  236: 2,
#  237: 6,
#  242: 1,
#  244: 1,
#  248: 2,
#  252: 1,
#  254: 1,
#  260: 1,
#  261: 1,
#  262: 1,
#  277: 1,
#  300: 3,
#  305: 1,
#  392: 11,
#  393: 3,
#  394: 1,
#  397: 1,
#  399: 1,
#  400: 2,
#  402: 4,
#  406: 1,
#  422: 5,
#  428: 1,
#  435: 2,
#  441: 1,
#  449: 1,
#  451: 1,
#  465: 2,
#  472: 1,
#  491: 2,
#  498: 0,
#  503: 1,
#  511: 2,
#  518: 1,
#  523: 3,
#  524: 1,
#  531: 1,
#  532: 1,
#  535: 1,
#  537: 2,
#  540: 1,
#  546: 2,
#  547: 2,
#  548: 2,
#  586: 1,
#  635: 1,
#  656: 0,
#  659: 0,
#  671: 1,
#  685: 1,
#  686: 1,
#  687: 1,
#  696: 4,
#  724: 3,
#  727: 3,
#  735: 1,
#  747: 1,
#  748: 2,
#  764: 0,
#  767: 1,
#  796: 2,
#  797: 2,
#  799: 2,
#  801: 2,
#  802: 6,
#  803: 6,
#  804: 1,
#  806: 2,
#  807: 2,
#  808: 1,
#  813: 1,
#  814: 10,
#  815: 1,
#  816: 1,
#  821: 2,
#  829: 1,
#  854: 1,
#  859: 0,
#  863: 1,
#  885: 11,
#  892: 1,
#  898: 1,
#  902: 2,
#  909: 0,
#  915: 0,
#  922: 8,
#  923: 11,
#  928: 11,
#  933: 8,
#  934: 1,
#  942: 0,
#  943: 2,
#  951: 1,
#  958: 1,
#  974: 0,
#  975: 0,
#  977: 0,
#  984: 1,
#  988: 3,
#  994: 4,
#  1000: 2,
#  1003: 4,
#  1007: 5,
#  1008: 3,
#  1037: 0,
#  1063: 1,
#  1085: 1,
#  1094: 0,
#  1138: 1,
#  1166: 0,
#  1185: 0,
#  1186: 0,
#  1187: 1,
#  1192: 0,
#  1198: 1,
#  1200: 2,
#  1210: 1,
#  1230: 3,
#  1233: 1,
#  1236: 1,
#  1237: 1,
#  1241: 6,
#  1252: 1,
#  1279: 2,
#  1283: 2,
#  1290: 2,
#  1300: 1,
#  1302: 1,
#  1306: 2,
#  1335: 0,
#  1336: 0,
#  1372: 3,
#  1380: 1,
#  1386: 2,
#  1414: 1,
#  1419: 1,
#  1432: 1,
#  1439: 1,
#  1446: 1,
#  1452: 1,
#  1483: 0,
#  1512: 1,
#  1555: 1,
#  1568: 1,
#  1589: 1,
#  1601: 2,
#  1609: 7,
#  1614: 1,
#  1695: 1,
#  1696: 2,
#  1707: 1,
#  1727: 1,
#  1736: 1,
#  1750: 1,
#  1911: 0,
#  2008: 1,
#  2009: 8,
#  2015: 1,
#  2065: 1,
#  2074: 1,
#  2084: 1,
#  2132: 0,
#  2169: 1,
#  2170: 1,
#  2238: 1,
#  2277: 1,
#  2298: 1,
#  2345: 3,
#  2349: 1,
#  2375: 1,
#  2418: 7,
#  2435: 1,
#  2467: 5,
#  2473: 1,
#  2482: 3,
#  2509: 2,
#  2513: 1,
#  2524: 1,
#  2553: 1,
#  2575: 1,
#  2585: 1,
#  2592: 1,
#  2606: 2,
#  2621: 4,
#  2696: 1,
#  2731: 1,
#  2738: 1,
#  2795: 2,
#  2798: 1,
#  2827: 1,
#  2853: 1,
#  2858: 1,
#  2869: 3,
#  2969: 8,
#  3051: 2,
#  3105: 1,
#  3136: 1,
#  3183: 1,
#  3216: 1,
#  3279: 0,
#  3301: 1,
#  3392: 1,
#  3398: 2,
#  3407: 0,
#  3429: 2,
#  3457: 2,
#  3474: 1,
#  3490: 1,
#  3492: 0,
#  3499: 0,
#  3524: 1,
#  3529: 0,
#  3637: 1,
#  3703: 6,
#  3705: 1,
#  3717: 0,
#  3723: 3,
#  3773: 0,
#  3952: 0,
#  3956: 0,
#  3979: 1,
#  4032: 1,
#  4060: 1,
#  4167: 1,
#  4195: 5,
#  4252: 1,
#  4486: 1,
#  4523: 1,
#  4524: 2,
#  4714: 2,
#  4730: 1,
#  4758: 1,
#  4808: 0,
#  4850: 0,
#  4917: 2,
#  4954: 0,
#  4974: 0,
#  4986: 1,
#  5009: 2,
#  5079: 1,
#  5178: 1,
#  5273: 0,
#  5282: 1,
#  5321: 2,
#  5346: 1,
#  5398: 0,
#  5412: 1,
#  5473: 1,
#  5625: 1,
#  5709: 0,
#  5794: 1,
#  5878: 1,
#  5960: 0,
#  6223: 1,
#  6276: 1,
#  6416: 1,
#  6514: 1,
#  6528: 1,
#  6556: 0,
#  6671: 1,
#  6728: 4,
#  6842: 1,
#  6908: 1,
#  7024: 0,
#  7125: 1,
#  7292: 1,
#  7453: 1,
#  7560: 1,
#  7585: 1,
#  7655: 1,
#  7709: 2,
#  7710: 7,
#  7725: 1,
#  7860: 0,
#  7870: 1,
#  7888: 1,
#  8129: 1,
#  8516: 1,
#  9136: 0,
#  9246: 0,
#  9336: 1,
#  9491: 1,
#  9521: 0,
#  9538: 2,
#  9822: 1,
#  9846: 0,
#  10091: 0,
#  10225: 0,
#  10422: 1,
#  10453: 2,
#  10679: 1,
#  10875: 1,
#  10882: 1,
#  11076: 0,
#  11150: 0,
#  11196: 1,
#  11199: 1,
#  11873: 0,
#  11927: 1,
#  11973: 1,
#  12022: 1,
#  12135: 1,
#  12908: 1,
#  13257: 2,
#  13258: 3,
#  13297: 3,
#  13827: 1,
#  13923: 0,
#  13958: 1,
#  14084: 1,
#  14554: 1,
#  14640: 1,
#  14730: 0,
#  15439: 1,
#  15588: 1,
#  15674: 1,
#  15800: 1,
#  15866: 1,
#  15869: 1,
#  15918: 2,
#  16153: 1,
#  16288: 1,
#  16496: 1,
#  16542: 1,
#  16742: 1,
#  16794: 1,
#  16863: 1,
#  17580: 1,
#  17733: 4,
#  17825: 1,
#  17871: 1,
#  18521: 0,
#  18623: 1,
#  18845: 0,
#  19258: 1,
#  19870: 1,
#  20436: 1,
#  20706: 0,
#  21327: 0,
#  21548: 2,
#  21923: 0,
#  21928: 0,
#  22760: 2,
#  23179: 0,
#  23735: 1,
#  23848: 0,
#  23884: 2,
#  25116: 1,
#  25413: 0,
#  25806: 0,
#  26327: 1,
#  26860: 1,
#  27305: 1,
#  28871: 2,
#  29575: 1,
#  30010: 0,
#  30347: 0,
#  30883: 0,
#  31307: 1,
#  41608: 0,
#  42197: 1,
#  43883: 0,
#  43884: 1,
#  44699: 1,
#  45405: 1,
#  46271: 1,
#  47599: 0,
#  48550: 1,
#  48636: 1,
#  49837: 2,
#  49905: 0,
#  50363: 1,
#  51360: 2,
#  51625: 1,
#  51907: 0,
#  52321: 1,
#  54123: 1,
#  55840: 3,
#  56908: 0,
#  60843: 2,
#  61251: 1,
#  61835: 1,
#  63097: 0,
#  65733: 1,
#  71918: 2,
#  85718: 1,
#  91380: 0,
#  92517: 1,
#  99285: 1,
#  101626: 0,
#  102481: 0,
#  103213: 1,
#  108301: 1,
#  145209: 0,
#  168121: 1,
#  181022: 2,
#  255822: 1,
#  271955: 1,
#  344043: 0,
#  344044: 2,
#  344045: 2,
#  380315: 2,
#  385234: 1,
#  445280: 1,
#  458799: 1,
#  459241: 2,
#  461991: 0,
#  599334: 1,
#  618152: 1,
#  620285: 1,
#  638520: 1,
#  734097: 0,
#  839277: 0,
#  859796: 1,
#  876818: 1,
#  939074: 0,
#  1009312: 1,
#  1224548: 0}

# %%
G.order()
# Out:
# 466

# %%
length = nx.single_source_shortest_path_length??

# %%
length = nx.single_source_shortest_path_length

# %%
weight_cut = 1.75
deg_cut = 30
for S in nx.connected_component_subgraphs(G):
    
    big_names = {}
    degree = nx.degree(S)
    node_degree = []
    for n in degree:
        if degree[n] > deg_cut:
            big_names[n] = S.node[n]['name']
            print(n,S.node[n]['name'], degree[n])
        node_degree.append(degree[n])
            
    keepedge = []
    for e in S.edges(data=True):
        if e[2]['weight'] < cut_val:
            continue
        else:
            keepedge.append((e[0],e[1]))
    
    nx.draw_graphviz(S,node_color=node_degree,node_size=node_degree,
                     alpha=0.3,edgelist=keepedge,labels=big_names,with_labels=True)
#nx.connected_components(G)
# Out:
# 26 Business 44
# 48 Engineering 31
# 128 History 59
# 184 Sociology 49
# 188 Cultural Studies 31
# 221 Psychology 46
# 4486 Political Science 37
# 392 Archaeology 31
# 18845 Environmental Sustainability 42
# 422 Computer Science 66
# 724 Economics 41
# 767 Anthropology 37
# 797 International Relations 50
# 803 Philosophy 62
# 859 Communication 46
# 922 Education 96
# 1237 Social Sciences 49
# 1372 Architecture 35
# 7710 Biology 31

# %%
def weighted_eccentricity(G, v=None, sp=None):
    e={}
    for n in G.nbunch_iter(v):
        if sp is None:
            length=nx.single_source_dijkstra_path_length(G,n,weight='distance')
            L = len(length)
        else:
            try:
                length=sp[n]
                L = len(length)
            except TypeError:
                raise nx.NetworkXError('Format of "sp" is invalid.')
        #if L != order:
        #    msg = "Graph not connected: infinite path length"
        #    raise networkx.NetworkXError(msg)
            
        e[n]=max(length.values())

    if v in G:
        return e[v]  # return single value
    else:
        return e

# %%
for S in nx.connected_component_subgraphs(G):
    
    ecc = nx.eccentricity(S)
    #print(ecc)
    ecc_list = []
    for key in ecc:
        ecc_list.append( (S.node[key]['name'], ecc[key]) )
    ecc_list.sort(key=lambda t: t[1], reverse=True)
    print(ecc_list[:10])
# Out:
# [('Epidemiology', 8), ('Structural Geology', 8), ('Medicine', 8), ('Business Ethics', 7), ('Telecommunications Engineering', 7), ('Fluid Dynamics', 7), ('Semantics', 7), ('Geology', 7), ('Construction Project Management', 7), ('Wind Energy', 7)]
# [('Pascal', 1), ('Logika Dan Algoritma', 1)]
# [('Direito', 1), ('Direito Constitucional', 1)]
# [('Pharmacy', 1), ('Pharmacology', 1)]
# [('Irrigation Systems Design', 3), ('Organic agriculture', 3), ('Tourism Marketing', 3), ('Tourism Management', 3), ('Cultural Tourism', 3), ('Hotel Management', 3), ('Hospitality Management', 2), ('Tourism', 2), ('Tourism Studies', 2)]
# [('Migration Studies', 1), ('Migration', 1)]
# [('Imperialism', 1), ('Empire', 1), ('Colonialism', 1)]
# [('Astrophysics', 1), ('Astronomy', 1)]
# [('Sport', 1), ('Physical Education', 1), ('Exercise Science', 1)]
# [('Byzantine Studies', 1), ('Late Antiquity', 1)]
# [('Comparative Civil Procedure', 1), ('Civil Procedure', 1)]
# [('Translation theory', 2), ('Translation', 2), ('Translation Studies', 1)]
# [('Logistics', 1), ('Supply Chain Management', 1)]
# [('Class', 1), ('Sex and Gender', 1)]
# [('Agriculture', 1), ('Agronomy', 1)]
# [('Citizenship', 1), ('Immigration Status & Nationality', 1)]
# [('Tecnologias da Informao e da Comunicao (TIC) na Educao', 1), ('Administrao e Gesto Educativa', 1)]
# [('Aquaculture', 1), ('Fish Biology', 1)]
# [('Islamic Finance', 1), ('Islamic Banking', 1)]
# [('Pemrograman Database', 1), ('Pemrograman VB 6.0', 1), ('Visual Basic 6.0', 1)]

# %%
all_ecc = []
for S in nx.connected_component_subgraphs(G):
    
    ecc = weighted_eccentricity(S)
    
    #print(ecc)
    ecc_list = []
    for key in ecc:
        ecc_list.append( (S.node[key]['name'], ecc[key]) )
    ecc_list.sort(key=lambda t: t[1], reverse=True)
    all_ecc.append(ecc_list)
    print("Top 5 Least related Research Interests")
    for name, val in ecc_list[:5]:
        print("\t",name,"\t",val)
    print("Top 5 Most related Research Interests")
    for name, val in ecc_list[-5:]:
        print("\t",name,"\t",val)
    print()
# Out:
# Top 5 Least related Research Interests
# 	 Semantics 	 4.45526913363
# 	 Medicine 	 4.45526913363
# 	 Epidemiology 	 4.39462987968
# 	 Community Development 	 4.34297216212
# 	 Aerodynamics 	 4.3225718525
# Top 5 Most related Research Interests
# 	 Sociology 	 2.25506013699
# 	 Philosophy 	 2.25447617305
# 	 History 	 2.24954830166
# 	 Social Sciences 	 2.24297618936
# 	 Education 	 2.22954081886
#
# Top 5 Least related Research Interests
# 	 Pascal 	 0.989707046714
# 	 Logika Dan Algoritma 	 0.989707046714
# Top 5 Most related Research Interests
# 	 Pascal 	 0.989707046714
# 	 Logika Dan Algoritma 	 0.989707046714
#
# Top 5 Least related Research Interests
# 	 Direito 	 0.627825213461
# 	 Direito Constitucional 	 0.627825213461
# Top 5 Most related Research Interests
# 	 Direito 	 0.627825213461
# 	 Direito Constitucional 	 0.627825213461
#
# Top 5 Least related Research Interests
# 	 Pharmacy 	 0.581125058113
# 	 Pharmacology 	 0.581125058113
# Top 5 Most related Research Interests
# 	 Pharmacy 	 0.581125058113
# 	 Pharmacology 	 0.581125058113
#
# Top 5 Least related Research Interests
# 	 Irrigation Systems Design 	 1.9518791806
# 	 Cultural Tourism 	 1.9518791806
# 	 Organic agriculture 	 1.92797259439
# 	 Tourism Management 	 1.66689615732
# 	 Tourism Marketing 	 1.59160150519
# Top 5 Most related Research Interests
# 	 Tourism Marketing 	 1.59160150519
# 	 Hotel Management 	 1.47762650301
# 	 Hospitality Management 	 1.32084491544
# 	 Tourism 	 1.20012144932
# 	 Tourism Studies 	 1.11910103269
#
# Top 5 Least related Research Interests
# 	 Migration Studies 	 0.812215724496
# 	 Migration 	 0.812215724496
# Top 5 Most related Research Interests
# 	 Migration Studies 	 0.812215724496
# 	 Migration 	 0.812215724496
#
# Top 5 Least related Research Interests
# 	 Empire 	 0.558035714286
# 	 Colonialism 	 0.558035714286
# 	 Imperialism 	 0.547405298883
# Top 5 Most related Research Interests
# 	 Empire 	 0.558035714286
# 	 Colonialism 	 0.558035714286
# 	 Imperialism 	 0.547405298883
#
# Top 5 Least related Research Interests
# 	 Astrophysics 	 0.423962352143
# 	 Astronomy 	 0.423962352143
# Top 5 Most related Research Interests
# 	 Astrophysics 	 0.423962352143
# 	 Astronomy 	 0.423962352143
#
# Top 5 Least related Research Interests
# 	 Physical Education 	 0.340506673931
# 	 Exercise Science 	 0.340506673931
# 	 Sport 	 0.33816915221
# Top 5 Most related Research Interests
# 	 Physical Education 	 0.340506673931
# 	 Exercise Science 	 0.340506673931
# 	 Sport 	 0.33816915221
#
# Top 5 Least related Research Interests
# 	 Byzantine Studies 	 0.399616368286
# 	 Late Antiquity 	 0.399616368286
# Top 5 Most related Research Interests
# 	 Byzantine Studies 	 0.399616368286
# 	 Late Antiquity 	 0.399616368286
#
# Top 5 Least related Research Interests
# 	 Comparative Civil Procedure 	 0.605620155039
# 	 Civil Procedure 	 0.605620155039
# Top 5 Most related Research Interests
# 	 Comparative Civil Procedure 	 0.605620155039
# 	 Civil Procedure 	 0.605620155039
#
# Top 5 Least related Research Interests
# 	 Translation theory 	 1.65073210332
# 	 Translation 	 1.65073210332
# 	 Translation Studies 	 0.990883868411
# Top 5 Most related Research Interests
# 	 Translation theory 	 1.65073210332
# 	 Translation 	 1.65073210332
# 	 Translation Studies 	 0.990883868411
#
# Top 5 Least related Research Interests
# 	 Logistics 	 0.508724627359
# 	 Supply Chain Management 	 0.508724627359
# Top 5 Most related Research Interests
# 	 Logistics 	 0.508724627359
# 	 Supply Chain Management 	 0.508724627359
#
# Top 5 Least related Research Interests
# 	 Class 	 0.922849760059
# 	 Sex and Gender 	 0.922849760059
# Top 5 Most related Research Interests
# 	 Class 	 0.922849760059
# 	 Sex and Gender 	 0.922849760059
#
# Top 5 Least related Research Interests
# 	 Agriculture 	 0.982994200334
# 	 Agronomy 	 0.982994200334
# Top 5 Most related Research Interests
# 	 Agriculture 	 0.982994200334
# 	 Agronomy 	 0.982994200334
#
# Top 5 Least related Research Interests
# 	 Citizenship 	 0.843953076209
# 	 Immigration Status & Nationality 	 0.843953076209
# Top 5 Most related Research Interests
# 	 Citizenship 	 0.843953076209
# 	 Immigration Status & Nationality 	 0.843953076209
#
# Top 5 Least related Research Interests
# 	 Tecnologias da Informao e da Comunicao (TIC) na Educao 	 0.99890120867
# 	 Administrao e Gesto Educativa 	 0.99890120867
# Top 5 Most related Research Interests
# 	 Tecnologias da Informao e da Comunicao (TIC) na Educao 	 0.99890120867
# 	 Administrao e Gesto Educativa 	 0.99890120867
#
# Top 5 Least related Research Interests
# 	 Aquaculture 	 0.663481953291
# 	 Fish Biology 	 0.663481953291
# Top 5 Most related Research Interests
# 	 Aquaculture 	 0.663481953291
# 	 Fish Biology 	 0.663481953291
#
# Top 5 Least related Research Interests
# 	 Islamic Finance 	 0.350988031308
# 	 Islamic Banking 	 0.350988031308
# Top 5 Most related Research Interests
# 	 Islamic Finance 	 0.350988031308
# 	 Islamic Banking 	 0.350988031308
#
# Top 5 Least related Research Interests
# 	 Pemrograman VB 6.0 	 0.848752334069
# 	 Visual Basic 6.0 	 0.848752334069
# 	 Pemrograman Database 	 0.845737483085
# Top 5 Most related Research Interests
# 	 Pemrograman VB 6.0 	 0.848752334069
# 	 Visual Basic 6.0 	 0.848752334069
# 	 Pemrograman Database 	 0.845737483085

# %%
import matplotlib.pyplot as plt

for cc_ecc in all_ecc:
    array = [ c[1] for c in cc_ecc]
    fig, ax = plt.subplots()
    plt.hist(array)
    plt.show()

# %%
import pandas as pd

# %%
df_weight = pd.DataFrame(names_byweight)
df_weight.columns = ["Field", "PageRank"]

# %%
df_weight.head()
# Out:
#               Field  PageRank
# 0         Education  0.047342
# 1   Social Sciences  0.032524
# 2           History  0.028545
# 3        Philosophy  0.025283
# 4  Computer Science  0.024607
#
# [5 rows x 2 columns]

# %%
df_weight.describe()
# Out:
#          PageRank
# count  466.000000
# mean     0.002146
# std      0.004093
# min      0.000393
# 25%      0.000545
# 50%      0.001035
# 75%      0.002146
# max      0.047342
#
# [8 rows x 1 columns]

# %%
df_weight['PageRank'].hist(bins=20)
