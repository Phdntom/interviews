# %%
import statsmodels.api as sm
import pandas as pd

# %%
data = pd.read_csv("http://www.ats.ucla.edu/stat/data/poisson_sim.csv")

# %%
data.head()
# Out:
#     id  num_awards  prog  math
# 0   45           0     3    41
# 1  108           0     1    41
# 2   15           0     3    44
# 3   67           0     3    42
# 4  153           0     3    40
#
# [5 rows x 4 columns]

# %%
data.describe()
# Out:
#                id  num_awards        prog        math
# count  200.000000  200.000000  200.000000  200.000000
# mean   100.500000    0.630000    2.025000   52.645000
# std     57.879185    1.052921    0.690477    9.368448
# min      1.000000    0.000000    1.000000   33.000000
# 25%     50.750000    0.000000    2.000000   45.000000
# 50%    100.500000    0.000000    2.000000   52.000000
# 75%    150.250000    1.000000    2.250000   59.000000
# max    200.000000    6.000000    3.000000   75.000000
#
# [8 rows x 4 columns]

# %%
dummy_ranks = pd.get_dummies(data['prog'], prefix='prog')
dummy_ranks.head()
# Out:
#    prog_1  prog_2  prog_3
# 0       0       0       1
# 1       1       0       0
# 2       0       0       1
# 3       0       0       1
# 4       0       0       1
#
# [5 rows x 3 columns]

# %%
cols_to_keep = ['num_awards', 'math']
frame = data[cols_to_keep].join(dummy_ranks)

# %%
frame.head()
# Out:
#    num_awards  math  prog_1  prog_2  prog_3
# 0           0    41       0       0       1
# 1           0    41       1       0       0
# 2           0    44       0       0       1
# 3           0    42       0       0       1
# 4           0    40       0       0       1
#
# [5 rows x 5 columns]

# %%
frame.describe()
# Out:
#        num_awards        math     prog_1      prog_2      prog_3
# count  200.000000  200.000000  200.00000  200.000000  200.000000
# mean     0.630000   52.645000    0.22500    0.525000    0.250000
# std      1.052921    9.368448    0.41863    0.500628    0.434099
# min      0.000000   33.000000    0.00000    0.000000    0.000000
# 25%      0.000000   45.000000    0.00000    0.000000    0.000000
# 50%      0.000000   52.000000    0.00000    1.000000    0.000000
# 75%      1.000000   59.000000    0.00000    1.000000    0.250000
# max      6.000000   75.000000    1.00000    1.000000    1.000000
#
# [8 rows x 5 columns]

# %%
keepers = ['math', 'prog_2', 'prog_3']
pois = sm.Poisson(frame['num_awards'], sm.add_constant(frame[keepers]) ).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.913761
#          Iterations 7

# %%
np.exp(pois.params)
# Out:
# const     0.005263
# math      1.072672
# prog_2    2.956065
# prog_3    1.447458
# dtype: float64

# %%
pois.tvalues
# Out:
# const    -7.968866
# math      6.618647
# prog_2    3.025402
# prog_3    0.838436
# dtype: float64

# %%
pois.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           Poisson Regression Results
# ...
# Dep. Variable:             num_awards   No. Observations:                  200
# Model:                        Poisson   Df Residuals:                      196
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 13 Jul 2014   Pseudo R-squ.:                  0.2118
# Time:                        09:16:09   Log-Likelihood:                -182.75
# converged:                       True   LL-Null:                       -231.86
#                                         LLR p-value:                 3.747e-21
# ...
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         -5.2471      0.658     -7.969      0.000        -6.538    -3.957
# math           0.0702      0.011      6.619      0.000         0.049     0.091
# ...
