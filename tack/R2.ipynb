# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5)
y = 5 * x + np.random.rand(len(x)) * 50
params = stats.linregress(x,y)
print(params[2] ** 2, params[0])
y_hat = params[0] * x + params[1]
plt.plot(x,y,'-',x,y_hat,'k--')
# Out:
# (0.27468151127361851, 6.3110970328756473)
# ...
