# %%
from __future__ import division, print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
# Read data and have a look
data = pd.read_csv('hw_data_clean.csv')
print('Number of records ', len(data))
data.head()
# Out:
# Number of records  10000
#    transaction_id  transacted_at  account_id  campaign_id  perk_id  \
# 0               1  8/1/2013 0:16        8540         6605     5083
# 1               2  8/1/2013 0:26        7020         9671     6924
# 2               3  8/1/2013 0:26        7354         8090     6116
# 3               4  8/1/2013 0:42        7004         6768      NaN
# 4               5  8/1/2013 1:00        7014         9036     4131
#
#    perk_amount  transaction_amount currency contributor_country  \
# 0           21                  21      USD       United States
# 1           15                  15      GBP       United States
# 2           10                  10      USD       United States
# 3          NaN                   1      USD       United States
# 4          315                 315      USD           Australia
#
#   campaign_country
# 0    United States
# 1   United Kingdom
# 2    United States
# 3    United States
# 4        Australia
#
# [5 rows x 10 columns]

# %%
clean_ts = [dt.datetime.strptime(ts, "%m/%d/%Y %H:%M") for ts in data.transacted_at]
data.transacted_at = clean_ts

# %%
dataUSD = data[ data.currency == 'USD']
dataUSD.describe()
# Out:
#        transaction_id    account_id   campaign_id      perk_id  perk_amount  \
# count     8810.000000   8810.000000   8810.000000  6129.000000  6129.000000
# mean      5010.859024   5014.512372   4967.965494  3472.136890    73.869147
# std       2902.183098   2901.552611   2880.040116  2008.269919   185.646168
# min          1.000000      1.000000      4.000000     1.000000     1.000000
# 25%       2471.250000   2480.250000   2483.000000  1723.000000    20.000000
# 50%       5023.500000   5046.500000   4984.000000  3475.000000    30.000000
# 75%       7536.750000   7538.750000   7495.000000  5194.000000    75.000000
# max      10000.000000  10000.000000  10000.000000  6975.000000  9000.000000
#
#        transaction_amount
# count         8810.000000
# mean            78.775369
# std            243.244723
# min              1.000000
# 25%             20.000000
# 50%             30.000000
# 75%             80.000000
# max          10000.000000
#
# [8 rows x 6 columns]

# %%
np.random.randint(20)
# Out:
# 8
